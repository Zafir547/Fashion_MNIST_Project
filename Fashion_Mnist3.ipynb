# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from keras.datasets import fashion_mnist
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras import regularizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import load_model

# %% [markdown]
# # Data Collection

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# # Data Annotation

# %%
class_labels = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Data Cleaning
#
#  - No missing values in Fashion MNIST.

# %% [markdown]
# Data Normalization

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# Train-Test Split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=2020)

# %% [markdown]
# Feature Extraction
#
#  - Done automatically by CNN layers.

# %% [markdown]
# Dimensionality Reduction

# %%
X_train = np.expand_dims(X_train, -1)
X_val   = np.expand_dims(X_val, -1)
X_test  = np.expand_dims(X_test, -1)

# %% [markdown]
# #  Image Augmentation

# %%
# Define ImageDataGenerator for training data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Fit the generator on training data
datagen.fit(X_train)

# %% [markdown]
# # **Callbacks Definitions**

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.5,  patience=3, min_lr=1e-6, verbose=1)

# %% [markdown]
# # **Model Selection**

# %% [markdown]
# ## Base CNN Model

# %%
cnn_model = Sequential([
    Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(2),
    Conv2D(64, 3, activation='relu', padding='same', strides=(2,2)),
    MaxPooling2D(2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(256, activation='relu'),
    Dropout(0.25),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 159,882
# Trainable params: 159,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile With Base CNN

# %%
cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Model Training With Base CNN

# %%
cnn_model.fit(X_train, y_train, epochs=20, batch_size=512, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 94/94 [==============================] - 2s 11ms/step - loss: 1.0102 - accuracy: 0.6317 - val_loss: 0.5789 - val_accuracy: 0.7754
# Epoch 2/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.5482 - accuracy: 0.7955 - val_loss: 0.4683 - val_accuracy: 0.8280
# Epoch 3/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4583 - accuracy: 0.8333 - val_loss: 0.3935 - val_accuracy: 0.8560
# Epoch 4/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.3938 - accuracy: 0.8573 - val_loss: 0.3589 - val_accuracy: 0.8718
# Epoch 5/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.3582 - accuracy: 0.8718 - val_loss: 0.3243 - val_accuracy: 0.8814
# Epoch 6/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.3336 - accuracy: 0.8781 - val_loss: 0.3133 - val_accuracy: 0.8847
# Epoch 7/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.3147 - accuracy: 0.8849 - val_loss: 0.3146 - val_accuracy: 0.8868
# Epoch 8/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2972 - accuracy: 0.8907 - val_loss: 0.3062 - val_accuracy: 0.8873
# Epoch 9/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2852 - accuracy: 0.8925 - val_loss: 0.2799 - val_accuracy: 0.8984
# Epoch 10/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2702 - accuracy: 0.9006 - val_loss: 0.2830 - val_accuracy: 0.8949
# Epoch 11/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2626 - accuracy: 0.9032 - val_loss: 0.2731 - val_accuracy: 0.9003
# Epoch 12/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2530 - accuracy: 0.9057 - val_loss: 0.2769 - val_accuracy: 0.9003
# Epoch 13/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2412 - accuracy: 0.9106 - val_loss: 0.2728 - val_accuracy: 0.9014
# Epoch 14/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2356 - accuracy: 0.9115 - val_loss: 0.2877 - val_accuracy: 0.8946
# Epoch 15/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2282 - accuracy: 0.9152 - val_loss: 0.2606 - val_accuracy: 0.9079
# Epoch 16/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2182 - accuracy: 0.9191 - val_loss: 0.2664 - val_accuracy: 0.9068
# Epoch 17/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2146 - accuracy: 0.9200 - val_loss: 0.2586 - val_accuracy: 0.9060
# Epoch 18/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2078 - accuracy: 0.9212 - val_loss: 0.2574 - val_accuracy: 0.9090
# Epoch 19/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2028 - accuracy: 0.9235 - val_loss: 0.2677 - val_accuracy: 0.9068
# Epoch 20/20
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1959 - accuracy: 0.9270 - val_loss: 0.2644 - val_accuracy: 0.9066

# %% [markdown]
# ## Model Evaluation With Base CNN

# %%
cnn_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2744 - accuracy: 0.9011
# [0.2744142413139343, 0.9010999798774719]

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Rebuild CNN model with updated hyperparameters
tuned_model = Sequential([
    Conv2D(64, 3, activation='relu', input_shape=(28,28,1)),  # Increased filters
    MaxPooling2D(2),
    Conv2D(128, 3, activation='relu', padding='same', strides=(2,2)), # More filters
    MaxPooling2D(2),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.3),                     # Higher dropout rate
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

tuned_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 256)               295168
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 469,642
# Trainable params: 469,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile with tuned learning rate

# %%
tuned_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the tuned model tuning with Callbacks

# %%
tuned_model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=256,        # Batch size is a tunable hyperparameter
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/30
# 188/188 [==============================] - 3s 12ms/step - loss: 0.7732 - accuracy: 0.7118 - val_loss: 0.4551 - val_accuracy: 0.8296 - lr: 0.0010
# Epoch 2/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.4272 - accuracy: 0.8431 - val_loss: 0.3810 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 3/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3541 - accuracy: 0.8704 - val_loss: 0.3369 - val_accuracy: 0.8792 - lr: 0.0010
# Epoch 4/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3163 - accuracy: 0.8846 - val_loss: 0.2944 - val_accuracy: 0.8920 - lr: 0.0010
# Epoch 5/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2847 - accuracy: 0.8957 - val_loss: 0.2757 - val_accuracy: 0.8985 - lr: 0.0010
# Epoch 6/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2578 - accuracy: 0.9047 - val_loss: 0.3041 - val_accuracy: 0.8885 - lr: 0.0010
# Epoch 7/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2422 - accuracy: 0.9114 - val_loss: 0.2673 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 8/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2298 - accuracy: 0.9146 - val_loss: 0.2688 - val_accuracy: 0.9022 - lr: 0.0010
# Epoch 9/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2131 - accuracy: 0.9218 - val_loss: 0.2640 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 10/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2042 - accuracy: 0.9228 - val_loss: 0.2586 - val_accuracy: 0.9100 - lr: 0.0010
# Epoch 11/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1908 - accuracy: 0.9296 - val_loss: 0.2773 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 12/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1757 - accuracy: 0.9350 - val_loss: 0.2811 - val_accuracy: 0.9074 - lr: 0.0010
# Epoch 13/30
# 188/188 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9372
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1689 - accuracy: 0.9372 - val_loss: 0.2677 - val_accuracy: 0.9114 - lr: 0.0010
# Epoch 14/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1369 - accuracy: 0.9498 - val_loss: 0.2629 - val_accuracy: 0.9143 - lr: 5.0000e-04
# Epoch 15/30
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1264 - accuracy: 0.9533 - val_loss: 0.2646 - val_accuracy: 0.9143 - lr: 5.0000e-04

# %% [markdown]
# ## Model Evaluation Tuning

# %%
tuned_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.9059
# [0.26697027683258057, 0.9059000015258789]

# %% [markdown]
# # Model Optimization

# %%
# Define L2 regularization strength
l2_reg = 0.001

# Optimized CNN Model
optimized_model = Sequential([
    # Convolutional Block 1
    Conv2D(64, 3, activation='relu', input_shape=(28, 28, 1), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),

    # Convolutional Block 2
    Conv2D(128, 3, activation='relu', padding='same', strides=(2,2), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),

    # Convolutional Block 3
    Conv2D(64, 3, activation='relu', padding='same', strides=(1,1), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),
    
    Flatten(),

    # Dense Block 1
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.5),

    # Dense Block 2
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.4),

    # Dense Block 3
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.25),

    # Dense Block 4
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),

    # Output
    Dense(10, activation='softmax')
])

# %% [markdown]
# ## Compile With Optimization

# %%
optimized_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the Model With Optimization

# %%
# Fit the model using data generator
history = optimized_model.fit(
    datagen.flow(X_train, y_train, batch_size=512),
    epochs=40,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/40
# 94/94 [==============================] - 9s 82ms/step - loss: 2.1758 - accuracy: 0.6055 - val_loss: 4.2220 - val_accuracy: 0.1008 - lr: 0.0010
# Epoch 2/40
# 94/94 [==============================] - 7s 79ms/step - loss: 1.6254 - accuracy: 0.7479 - val_loss: 4.6318 - val_accuracy: 0.1331 - lr: 0.0010
# Epoch 3/40
# 94/94 [==============================] - 7s 77ms/step - loss: 1.3873 - accuracy: 0.7812 - val_loss: 4.1633 - val_accuracy: 0.1430 - lr: 0.0010
# Epoch 4/40
# 94/94 [==============================] - 7s 77ms/step - loss: 1.1973 - accuracy: 0.8029 - val_loss: 3.0457 - val_accuracy: 0.2255 - lr: 0.0010
# Epoch 5/40
# 94/94 [==============================] - 7s 78ms/step - loss: 1.0357 - accuracy: 0.8187 - val_loss: 2.0358 - val_accuracy: 0.3661 - lr: 0.0010
# Epoch 6/40
# 94/94 [==============================] - 7s 77ms/step - loss: 0.9181 - accuracy: 0.8295 - val_loss: 1.1064 - val_accuracy: 0.7106 - lr: 0.0010
# Epoch 7/40
# 94/94 [==============================] - 8s 80ms/step - loss: 0.8195 - accuracy: 0.8361 - val_loss: 0.8487 - val_accuracy: 0.7911 - lr: 0.0010
# Epoch 8/40
# 94/94 [==============================] - 7s 79ms/step - loss: 0.7498 - accuracy: 0.8398 - val_loss: 0.7717 - val_accuracy: 0.8126 - lr: 0.0010
# Epoch 9/40
# 94/94 [==============================] - 7s 77ms/step - loss: 0.6979 - accuracy: 0.8429 - val_loss: 0.6944 - val_accuracy: 0.8291 - lr: 0.0010
# Epoch 10/40
# 94/94 [==============================] - 7s 77ms/step - loss: 0.6488 - accuracy: 0.8480 - val_loss: 0.6823 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 11/40
# 94/94 [==============================] - 7s 78ms/step - loss: 0.6134 - accuracy: 0.8533 - val_loss: 0.5878 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 12/40
# 94/94 [==============================] - 7s 78ms/step - loss: 0.5850 - accuracy: 0.8556 - val_loss: 0.6033 - val_accuracy: 0.8462 - lr: 0.0010
# Epoch 13/40
# 94/94 [==============================] - 7s 79ms/step - loss: 0.5680 - accuracy: 0.8538 - val_loss: 0.5544 - val_accuracy: 0.8558 - lr: 0.0010
# Epoch 14/40
# 94/94 [==============================] - 7s 79ms/step - loss: 0.5405 - accuracy: 0.8590 - val_loss: 0.4987 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 15/40
# 94/94 [==============================] - 7s 77ms/step - loss: 0
40
# 94/94 [==============================] - 7s 78ms/step - loss: 0.3570 - accuracy: 0.9023 - val_loss: 0.3580 - val_accuracy: 0.8978 - lr: 1.2500e-04
# Epoch 38/40
# 94/94 [==============================] - 7s 79ms/step - loss: 0.3538 - accuracy: 0.8996 - val_loss: 0.3648 - val_accuracy: 0.8942 - lr: 1.2500e-04
# Epoch 39/40
# 94/94 [==============================] - 7s 78ms/step - loss: 0.3479 - accuracy: 0.9014 - val_loss: 0.3473 - val_accuracy: 0.9028 - lr: 1.2500e-04
# Epoch 40/40
# 94/94 [==============================] - 7s 77ms/step - loss: 0.3459 - accuracy: 0.9013 - val_loss: 0.3685 - val_accuracy: 0.8904 - lr: 1.2500e-04

# %% [markdown]
# ## Model Evaluation With Optimization

# %%
optimized_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3764 - accuracy: 0.8876
# [0.3763890266418457, 0.8876000046730042]

# %% [markdown]
# # **Visualization and Evaluation**

# %% [markdown]
# ## Plot Training and Validation Accuracy & Loss

# %%
# Accuracy plot
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Display Sample Predictions

# %%
plt.figure(figsize=(16, 30))
j = 1
for i in np.random.randint(0, 1000, 60):
    plt.subplot(10, 6, j); j += 1
    plt.imshow(X_test[i].reshape(28, 28), cmap='Greys')
    plt.title('Actual = {} / {} \nPredicted = {} / {}'.format(
        class_labels[y_test[i]], y_test[i],
        class_labels[np.argmax(optimized_model.predict(np.expand_dims(X_test[i], axis=0)))],
        np.argmax(optimized_model.predict(np.expand_dims(X_test[i], axis=0)))
    ))
    plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 374us/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 810us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step

# %% [markdown]
# Predict Labels from Model

# %%
# Predict on test set
y_pred = optimized_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Confusion Matrix

# %%
# Confusion confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred_classes, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.90      0.72      0.80      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.91      0.80      0.85      1000
#        Dress       0.93      0.86      0.89      1000
#         Coat       0.82      0.83      0.83      1000
#       Sandal       0.96      0.98      0.97      1000
#        Shirt       0.60      0.81      0.69      1000
#      Sneaker       0.94      0.95      0.95      1000
#          Bag       0.96      0.99      0.98      1000
#   Ankle boot       0.98      0.94      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.90      0.89      0.89     10000
# weighted avg       0.90      0.89      0.89     10000

# %% [markdown]
# Accuracy Score

# %%
test_accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Test Accuracy Score: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy Score: 88.76%

# %% [markdown]
# # **Model Deployment**

# %% [markdown]
# Save the Entire Model (Recommended for deployment)

# %%
optimized_model.save('fashion_mnist_cnn_optimized_model(2).h5')

# %% [markdown]
# Load the Saved Model

# %%
# Load the trained model
loaded_model = load_model('fashion_mnist_cnn_optimized_model(2).h5')

# Predict on a single sample
sample = np.expand_dims(X_test[0], axis=0)
prediction = loaded_model.predict(sample)

print("Predicted Label:", np.argmax(prediction))
print("Actual Label:", y_test[0])
# Out:
# 1/1 [==============================] - 0s 116ms/step
# Predicted Label: 9
# Actual Label: 9
